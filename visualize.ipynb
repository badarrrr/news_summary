# %% [markdown]
# # Visualization of Topic Summaries and Article Summaries

# %%
from pathlib import Path
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
import umap
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 解析单个 html
def parse_html(path):
    with open(path, encoding='utf-8') as f:
        soup = BeautifulSoup(f, 'lxml')

    # 1.1 Topic-Summary
    label = soup.find('div', class_='container').find('h1').get_text()

    topic_summary = soup.find('div', class_='summary-content').get_text()

    # 1.2 Source-Articles
    articles = []
    for card in soup.select('div.article-card'):
        title = card.select_one('.article-title a').get_text(strip=True)
        content = card.select_one('.article-content').get_text(strip=True)
        articles.append(title + ' ' + content)

    return topic_summary, articles, label

# %%
topic_summary, articles, label = parse_html('./html/Tesla.html')

# %%
topic_summary
# Out:
# 'Tesla faces significant challenges in 2025 amid declining sales, political controversies, and regulatory scrutiny, while Elon Musk secures a historic $1 trillion performance-based pay package from shareholders. Despite these headwinds, investor confidence remains strong due to Musk’s vision of transforming Tesla into an AI and robotics leader.\n\n1. In October 2025, Tesla’s China sales fell 35.8% year-on-year to 26,006 vehicles—the lowest in three years—while its market share dropped to 3.2%. European sales also declined sharply, with a 40% drop in Germany.\n\n2. On November 6, 2025, over 75% of Tesla shareholders approved a pay package granting Musk up to 423.7 million shares if Tesla reaches a $8.5 trillion market cap and meets aggressive targets, including selling 20 million vehicles and deploying one million robotaxis and robots.\n\n3. Tesla reported a 37% year-on-year profit decline in Q3 2025 despite record revenue of $28.1 billion, driven by last-minute purchases before the U.S. $7,500 EV tax credit expired on October 1.\n\n4. Regulatory investigations intensified, with NHTSA probing 58 incidents involving Tesla’s Full Self-Driving feature and delays in crash reporting. The company also recalled over 63,000 Cybertrucks for excessively bright headlights.\n\n5. Musk’s political activities, including support for Donald Trump and far-right European politicians, have alienated environmentally conscious buyers, costing Tesla an estimated 1–1.26 million U.S. sales since late 2022.\n\nInvestor focus has shifted from Tesla’s core automotive business—which accounts for only 12% of valuation—to futuristic AI and robotics ventures, reflecting a high-risk, high-reward trajectory dependent on Musk’s leadership.'

# %%
label
# Out:
# 'Tesla Musk Pay Package'

# %%
len(articles)
# Out:
# 39

# %%
articles[0]
# Out:
# 'Tesla’s China sales fall to 3-year low amid tepid demand Tesla’s(TSLA.O)sales in China dropped to 26,006 vehicles in October, their lowest in three years, as the US electric vehicle maker struggles with tepid demand in the hyper-competitive market. Sales fe...'

# %%
# 2. 批量解析
html_dir = Path('html')          # 存放所有 html 的目录
records = []                      # 每个元素：(text, label, html_id, role)
for idx, html in enumerate(html_dir.glob('*.html')):
    summary, arts, lab = parse_html(html)
    records.append((summary, lab, 'topic'))
    for art in arts:
        records.append((art, lab, 'article'))

df = pd.DataFrame(records, columns=['text', 'label', 'role'])

# %%
df.label.unique()
# Out:
# array(['Zootopia 2 Release', 'Tesla Musk Pay Package'], dtype=object)

# %%
# 3. TF-IDF 向量化
tfidf = TfidfVectorizer(stop_words='english', max_features=20000, ngram_range=(1,2))
X = tfidf.fit_transform(df.text)        # scipy sparse matrix
y = df.label.values

# %%
tfidf.vocabulary_
# Out:
# {'release': np.int64(1641),
#  'zootopia': np.int64(2393),
#  'emerged': np.int64(682),
#  'major': np.int64(1147),
#  'cultural': np.int64(524),
#  'box': np.int64(312),
#  'office': np.int64(1357),
#  'event': np.int64(718),
#  'late': np.int64(1074),
#  '2025': np.int64(27),
#  'marking': np.int64(1180),
#  'significant': np.int64(1905),
#  'moment': np.int64(1231),
#  'animated': np.int64(155),
#  'films': np.int64(787),
#  'broader': np.int64(331),
#  'theatrical': np.int64(2106),
#  'landscape': np.int64(1065),
#  'scheduled': np.int64(1816),
#  'november': np.int64(1340),
#  '26': np.int64(40),
#  'disney': np.int64(611),
#  'continuing': np.int64(486),
#  'adventures': np.int64(109),
#  'judy': np.int64(1027),
#  'hopps': np.int64(930),
#  'nick': np.int64(1327),
#  'wilde': np.int64(2320),
#  'animal': np.int64(151),
#  'metropolis': np.int64(1202),
#  'film': np.int64(783),
#  'anticipated': np.int64(167),
#  'drive': np.int64(645),
#  'strong': np.int64(1975),
#  'audience': np.int64(230),
#  'turnout': np.int64(2208),
#  'thanksgiving': np.int64(2097),
#  'holiday': np.int64(924),
#  'period': np.int64(1443),
#  'following': np.int64(807),
#  'success': np.int64(1986),
#  'releases': np.int64(1648),
#  'like': np.int64(1109),
#  'wicked': np.int64(2316),
#  'good': np.int64(866),
#  'earned': np.int64(668),
#  '226': np.int64(34),
#  'million': np.int64(1204),
#  'globally': np.int64(858),
#  'opening': np.int64(1377),
#  'weekend': np.int64(2309),
#  'eligible': np.int64(676),
#  '98th': np.int64(86),
#  'academy': np.int64(88),
#  'awards': np.int64(253),
#  'feature': np.int64(758),
#  'category': np.int64(380),
#  'having': np.int64(900),
#  'completed': np.int64(472),
#  'qualifying': np.int64(1575),
#  'run': np.int64(1751),
#  'key': np.int64(1045),
#  'cities': np.int64(428),
#  'including': np.int64(969),
#  'new': np.int64(1316),
#  'york': np.int64(2377),
#  'los': np.int64(1132),
#  'angeles': np.int64(145),
#  'san': np.int64(1796),
#  'francisco': np.int64(825),
#  'industry': np.int64(982),
#  'analysts': np.int64(143),
#  'project': np.int64(1546),
#  'alongside': np.int64(132),
#  'avatar': np.int64(245),
#  'ash': np.int64(213),
#  'help': np.int64(908),
#  'push': np.int64(1571),
#  'annual': np.int64(164),
#  'domestic': np.int64(623),
#  'billion': np.int64(294),
#  'post': np.int64(1508),
#  'pandemic': np.int64(1416),
#  'target': np.int64(2014),
#  'sluggish': np.int64(1920),
#  'fall': np.int64(746),
#  'season': np.int64(1822),
#  'underscores': np.int64(2221),
#  'continued': np.int64(484),
#  'importance': np.int64(959),
#  'family': np.int64(751),
#  'friendly': np.int64(831),
#  'sequels': np.int64(1851),
#  'revitalizing': np.int64(1688),
#  'cinema': np.int64(426),
#  'attendance': np.int64(228),
#  'shaping': np.int64(1860),
#  'year': np.int64(2359),
#  'end': np.int64(687),
#  'performance': np.int64(1441),
#  'release zootopia': np.int64(1645),
#  'zootopia emerged': np.int64(2396),
#  'emerged major': np.int64(683),
#  'major cultural': np.int64(1148),
#  'cultural box': np.int64(525),
#  'box office': np.int64(313),
#  'office event': np.int64(1360),
#  'event late': np.int64(719),
#  'late 2025': np.int64(1076),
#  '2025 marking': np.int64(32),
#  'marking significant': np.int64(1182),
#  'significant moment': np.int64(1907),
#  'moment animated': np.int64(1232),
#  'animated films': np.int64(157),
#  'films broader': np.int64(788),
#  'broader theatrical': np.int64(332),
#  'theatrical landscape': np.int64(2107),
#  'landscape zootopia': np.int64(1066),
#  'zootopia scheduled': np.int64(2397),
#  'scheduled theatrical': np.int64(1817),
#  'theatrical release': np.int64(2108),
#  'release november': np.int64(1642),
#  'november 26': np.int64(1342),
#  '26 2025': np.int64(42),
#  '2025 disney': np.int64(31),
#  'disney continuing': np.int64(612),
#  'continuing adventures': np.int64(487),
#  'adventures judy': np.int64(110),
#  'judy hopps': np.int64(1028),
#  'hopps nick': np.int64(931),
#  'nick wilde': np.int64(1328),
#  'wilde animal': np.int64(2321),
#  'animal metropolis': np.int64(152),
#  'metropolis film': np.int64(1203),
#  'film anticipated': np.int64(784),
#  'anticipated drive': np.int64(169),
#  'drive strong': np.int64(646),
#  'strong audience': np.int64(1976),
#  'audience turnout': np.int64(231),
#  'turnout thanksgiving': np.int64(2209),
#  'thanksgiving holiday': np.int64(2098),
#  'holiday period': np.int64(925),
#  'period following': np.int64(1444),
#  'following success': np.int64(809),
#  'success major': np.int64(1987),
#  'major releases': np.int64(1150),
#  'releases like': np.int64(1649),
#  'like wicked': np.int64(1112),
#  'wicked good': np.int64(2319),
#  'good earned': np.int64(867),
#  'earned 226': np.int64(669),
#  '226 million': np.int64(35),
#  'million globally': np.int64(1208),
#  'globally opening': np.int64(859),
#  'opening weekend': np.int64(1380),
#  'weekend zootopia': np.int64(2311),
#  'zootopia eligible': np.int64(2395),
#  'eligible 98th': np.int64(677),
#  '98th academy': np.int64(87),
#  'academy awards': np.int64(89),
#  'awards animated': np.int64(254),
#  'animated feature': np.int64(156),
#  'feature category': np.int64(759),
#  'category having': np.int64(382),
#  'having completed': np.int64(901),
#  'completed qualifying': np.int64(473),
#  'qualifying theatrical': np.int64(1576),
#  'theatrical run': np.int64(2109),
#  'run key': np.int64(1753),
#  'key cities': np.int64(1046),
#  'cities including': np.int64(429),
#  'including new': np.int64(970),
#  'new york': np.int64(1321),
#  'york los': np.int64(2379),
#  'los angeles': np.int64(1133),
#  'angeles san': np.int64(146),
#  'san francisco': np.int64(1797),
#  'francisco industry': np.int64(826),
#  'industry analysts': np.int64(983),
#  'analysts project': np.int64(144),
#  'project zootopia': np.int64(1547),
#  'zootopia alongside': np.int64(2394),
#  'alongside avatar': np.int64(133),
#  'avatar ash': np.int64(246),
#  'ash help': np.int64(214),
#  'help push': np.int64(909),
#  'push annual': np.int64(1572),
#  'annual domestic': np.int64(165),
#  'domestic box': np.int64(624),
#  'office billion': np.int64(1359),
#  'billion post': np.int64(297),
#  'post pandemic': np.int64(1509),
#  'pandemic target': np.int64(1417),
#  'target sluggish': np.int64(2015),
#  'sluggish fall': np.int64(1921),
#  'fall season': np.int64(749),
#  'season film': np.int64(1823),
#  'film release': np.int64(786),
#  'release underscores': np.int64(1644),
#  'underscores continued': np.int64(2222),
#  'continued importance': np.int64(485),
#  'importance family': np.int64(960),
#  'family friendly': np.int64(752),
#  'friendly sequels': np.int64(832),
#  'sequels revitalizing': np.int64(1852),
#  'revitalizing cinema': np.int64(1689),
#  'cinema attendance': np.int64(427),
#  'attendance shaping': np.int64(229),
#  'shaping year': np.int64(1861),
#  'year end': np.int64(2363),
#  'end box': np.int64(688),
#  'office performance': np.int64(1363),
#  'smithsonian': np.int64(1924),
#  'museums': np.int64(1254),
#  'national': np.int64(1300),
#  'zoo': np.int64(2382),
#  'reopenings': np.int64(1654),
#  'bring': np.int64(329),
#  'flocks': np.int64(799),
#  'visitors': np.int64(2270),
#  'welcoming': np.int64(2314),
#  'members': np.int64(1198),
#  'public': np.int64(1564),
#  'weeks': np.int64(2312),
#  'closures': np.int64(443),
#  'government': np.int64(870),
#  'shutdown': np.int64(1896),
#  'institution': np.int64(993),
#  'receives': np.int64(1618),
#  'federal': np.int64(766),
#  'fundin': np.int64(835),
#  'smithsonian museums': np.int64(1927),
#  'museums national': np.int64(1255),
#  'national zoo': np.int64(1301),
#  'zoo reopenings': np.int64(2390),
#  'reopenings bring': np.int64(1655),
#  'bring flocks': np.int64(330),
#  'flocks visitors': np.int64(800),
#  'visitors smithsonian': np.int64(2271),
#  'zoo welcoming': np.int64(2392),
#  'welcoming members': np.int64(2315),
#  'members public': np.int64(1199),
#  'public weeks': np.int64(1565),
#  'weeks closures': np.int64(2313),
#  'closures government': np.int64(444),
#  'government shutdown': np.int64(871),
#  'shutdown smithsonian': np.int64(1898),
#  'smithsonian institution': np.int64(1926),
#  'institution receives': np.int64(995),
#  'receives federal': np.int64(1619),
#  'federal fundin': np.int64(769),
#  'close': np.int64(439),
#  'drags': np.int64(639),
#  'shut': np.int64(1894),
#  'doors': np.int64(632),
#  'sunday': np.int64(1990),
#  'thegovernment': np.int64(2110),
#  'shutdownenters': np.int64(1899),
#  'week': np.int64(2304),
#  'posted': np.int64(1510),
#  'website': np.int64(2302),
#  'institute': np.int64(991),
#  '19': np.int64(11),
#  'museu': np.int64(1253),
#  'zoo close': np.int64(2384),
#  'close government': np.int64(440),
#  'shutdown drags': np.int64(1897),
#  'drags smithsonian': np.int64(640),
#  'zoo shut': np.int64(2391),
#  'shut doors': np.int64(1895),
#  'doors sunday': np.int64(634),
#  'sunday thegovernment': np.int64(1994),
#  'thegovernment shutdownenters': np.int64(2111),
#  'shutdownenters week': np.int64(1900),
#  'week smithsonian': np.int64(2307),
#  'institution posted': np.int64(994),
#  'posted website': np.int64(1511),
#  'website smithsonian': np.int64(2303),
#  'smithsonian institute': np.int64(1925),
#  'institute 19': np.int64(992),
#  '19 museu': np.int64(12),
#  'denmark': np.int64(583),
#  'asks': np.int64(219),
#  'people': np.int64(1438),
#  'donate': np.int64(628),
#  'unwanted': np.int64(2236),
#  'pets': np.int64(1451),
#  'feed': np.int64(773),
#  'predators': np.int64(1519),
#  'imitate': np.int64(957),
#  'natural': np.int64(1302),
#  'food': np.int64(810),
#  'chain': np.int64(395),
#  'northern': np.int64(1336),
#  'asking': np.int64(217),
#  'pet': np.int64(1449),
#  'owners': np.int64(1394),
#  'guinea': np.int64(892),
#  'pigs': np.int64(1463),
#  'rabbits': np.int64(1588),
#  'chickens': np.int64(410),
#  'small': np.int64(1922),
#  'horses': np.int64(934),
#  'display': np.int64(613),
#  'denmark zoo': np.int64(585),
#  'zoo asks': np.int64(2383),
#  'asks people': np.int64(221),
#  'people donate': np.int64(1440),
#  'donate unwanted': np.int64(629),
#  'unwanted pets': np.int64(2238),
#  'pets feed': np.int64(1452),
#  'feed predators': np.int64(774),
#  'predators imitate': np.int64(1520),
#  'imitate natural': np.int64(958),
#  'natural food': np.int64(1303),
#  'food chain': np.int64(811),
#  'chain zoo': np.int64(396),
#  'zoo northern': np.int64(2388),
#  'northern denmark': np.int64(1337),
#  'denmark asking': np.int64(584),
#  'asking pet': np.int64(218),
#  'pet owners': np.int64(1450),
#  'owners donate': np.int64(1395),
#  'unwanted guinea': np.int64(2237),
#  'guinea pigs': np.int64(893),
#  'pigs rabbits': np.int64(1464),
#  'rabbits chickens': np.int64(1589),
#  'chickens small': np.int64(411),
#  'small horses': np.int64(1923),
#  'horses display': np.int64(935),
#  'display feed': np.int64(614),
#  'feed zoo': np.int64(775),
#  'zoo predators': np.int64(2389),
#  'german': np.int64(846),
#  'kills': np.int64(1053),
#  '12': np.int64(7),
#  'baboons': np.int64(261),
#  'didn': np.int64(601),
#  'space': np.int64(1937),
#  'house': np.int64(938),
#  'despite': np.int64(592),
#  'protests': np.int64(1559),
#  'berlin': np.int64(277),
#  'ap': np.int64(170),
#  'city': np.int64(430),
#  'nuremberg': np.int64(1343),
#  'said': np.int64(1764),
#  'killed': np.int64(1051),
#  'tuesday': np.int64(2195),
#  'capping': np.int64(361),
#  'saga': np.int64(1762),
#  'rooted': np.int64(1740),
#  'concerns': np.int64(474),
#  'little': np.int64(1117),
#  'growing': np.int64(885),
#  'group': np.int64(884),
#  'german zoo': np.int64(848),
#  'zoo kills': np.int64(2386),
#  'kills 12': np.int64(1054),
#  '12 baboons': np.int64(8),
#  'baboons didn': np.int64(262),
#  'didn space': np.int64(602),
#  'space house': np.int64(1938),
#  'house despite': np.int64(939),
#  'despite protests': np.int64(594),
#  'protests berlin': np.int64(1560),
#  'berlin ap': np.int64(278),
#  'ap zoo': np.int64(189),
#  'zoo german': np.int64(2385),
#  'german city': np.int64(847),
#  'city nuremberg': np.int64(433),
#  'nuremberg said': np.int64(1344),
#  'said killed': np.int64(1766),
#  'killed 12': np.int64(1052),
#  'baboons tuesday': np.int64(263),
#  'tuesday despite': np.int64(2196),
#  'protests capping': np.int64(1561),
#  'capping saga': np.int64(362),
#  'saga rooted': np.int64(1763),
#  'rooted concerns': np.int64(1741),
#  'concerns zoo': np.int64(475),
#  'zoo little': np.int64(2387),
#  'little space': np.int64(1118),
#  'house growing': np.int64(940),
#  'growing group': np.int64(886),
#  'ukraine': np.int64(2214),
#  'peace': np.int64(1434),
#  'talks': np.int64(2012),
#  'geneva': np.int64(844),
#  'ukrainian': np.int64(2217),
#  'officials': np.int64(1367),
#  'progress': np.int64(1544),
#  'ending': np.int64(692),
#  'therussia': np.int64(2114),
#  'warbut': np.int64(2291),
#  'provided': np.int64(1562),
#  'scant': np.int64(1812),
#  'details': np.int64(597),
#  'discussing': np.int64(607),
#  'theamerican': np.int64(2099),
#  'proposalto': np.int64(1554),
#  'achieve': np.int64(95),
#  'ukraine peace': np.int64(2215),
#  'peace talks': np.int64(1435),
#  'talks geneva': np.int64(2013),
#  'geneva ap': np.int64(845),
#  'ap ukrainian': np.int64(185),
#  'ukrainian officials': np.int64(2218),
#  'officials said': np.int64(1368),
#  'said sunday': np.int64(1772),
#  'sunday progress': np.int64(1993),
#  'progress ending': np.int64(1545),
#  'ending therussia': np.int64(693),
#  'therussia ukraine': np.int64(2115),
#  'ukraine warbut': np.int64(2216),
#  'warbut provided': np.int64(2292),
#  'provided scant': np.int64(1563),
#  'scant details': np.int64(1813),
#  'details discussing': np.int64(598),
#  'discussing theamerican': np.int64(608),
#  'theamerican proposalto': np.int64(2100),
#  'proposalto achieve': np.int64(1555),
#  'achieve peace': np.int64(96),
#  'morgan': np.int64(1246),
#  'geyser': np.int64(851),
#  'madison': np.int64(1138),
#  'wis': np.int64(2327),
#  'wisconsin': np.int64(2329),
#  'woman': np.int64(2331),
#  'admitted': np.int64(107),
#  'nearlystabbing': np.int64(1307),
#  'classmate': np.int64(434),
#  'deathat': np.int64(548),
#  'age': np.int64(111),
#  'online': np.int64(1372),
#  'horror': np.int64(932),
#  'character': np.int64(404),
#  'slender': np.int64(1908),
#  'man': np.int64(1162),
#  'missing': np.int64(1220),
#  'cut': np.int64(526),
#  'electronic': np.int64(674),
#  'monitor': np.int64(1238),
#  'morgan geyser': np.int64(1247),
#  'geyser madison': np.int64(852),
#  'madison wis': np.int64(1139),
#  'wis ap': np.int64(2328),
#  'ap wisconsin': np.int64(188),
#  'wisconsin woman': np.int64(2330),
#  'woman admitted': np.int64(2332),
#  'admitted nearlystabbing': np.int64(108),
#  'nearlystabbing classmate': np.int64(1308),
#  'classmate deathat': np.int64(435),
#  'deathat age': np.int64(549),
#  'age 12': np.int64(112),
#  '12 online': np.int64(9),
#  'online horror': np.int64(1373),
#  'horror character': np.int64(933),
#  'character slender': np.int64(405),
#  'slender man': np.int64(1909),
#  'man missing': np.int64(1165),
#  'missing cut': np.int64(1221),
#  'cut electronic': np.int64(527),
#  'electronic monitor': np.int64(675),
#  'chiefs': np.int64(414),
#  'beat': np.int64(272),
#  'colts': np.int64(451),
#  'kansas': np.int64(1037),
#  'mo': np.int64(1222),
#  'looked': np.int64(1128),
#  'quarters': np.int64(1584),
#  'indianapolis': np.int64(978),
#  'offense': np.int64(1351),
#  'stuck': np.int64(1980),
#  'rut': np.int64(1758),
#  'penalties': np.int64(1436),
#  'pilin': np.int64(1465),
#  'chiefs beat': np.int64(415),
#  'beat colts': np.int64(273),
#  'colts kansas': np.int64(452),
#  'kansas city': np.int64(1038),
#  'city mo': np.int64(432),
#  'mo ap': np.int64(1223),
#  'ap kansas': np.int64(180),
#  'city chiefs': np.int64(431),
#  'chiefs looked': np.int64(416),
#  'looked like': np.int64(1129),
#  'like season': np.int64(1111),
#  'season quarters': np.int64(1824),
#  'quarters indianapolis': np.int64(1585),
#  'indianapolis sunday': np.int64(979),
#  'sunday offense': np.int64(1992),
#  'offense stuck': np.int64(1352),
#  'stuck rut': np.int64(1981),
#  'rut penalties': np.int64(1759),
#  'penalties pilin': np.int64(1437),
#  '25': np.int64(36),
#  'follow': np.int64(805),
#  'live': np.int64(1119),
#  'updates': np.int64(2239),
#  'theap': np.int64(2101),
#  'poll': np.int64(1497),
#  'college': np.int64(447),
#  'football': np.int64(812),
#  'polldelivered': np.int64(1500),
#  'straight': np.int64(1964),
#  'inbox': np.int64(964),
#  'alerts': np.int64(128),
#  'sign': np.int64(1903),
#  'oregon': np.int64(1383),
#  'returned': np.int64(1679),
#  'oft': np.int64(1369),
#  'ap 25': np.int64(171),
#  '25 follow': np.int64(38),
#  'follow live': np.int64(806),
#  'live updates': np.int64(1120),
#  'updates theap': np.int64(2240),
#  'theap 25': np.int64(2102),
#  '25 poll': np.int64(39),
#  'poll theap': np.int64(1499),
#  '25 college': np.int64(37),
#  'college football': np.int64(448),
#  'football polldelivered': np.int64(813),
#  'polldelivered straight': np.int64(1501),
#  'straight inbox': np.int64(1966),
#  'inbox week': np.int64(965),
#  'week ap': np.int64(2305),
#  'poll alerts': np.int64(1498),
#  'alerts sign': np.int64(129),
#  'sign oregon': np.int64(1904),
#  'oregon returned': np.int64(1384),
#  'returned oft': np.int64(1680),
#  'donald': np.int64(625),
#  'glover': np.int64(860),
#  'recent': np.int64(1620),
#  'health': np.int64(906),
#  'scare': np.int64(1814),
#  'forced': np.int64(816),
#  'tocancel': np.int64(2140),
#  'tour': np.int64(2146),
#  'time': np.int64(2137),
#  'described': np.int64(590),
#  'ailment': np.int64(124),
#  'saturday': np.int64(1800),
#  'night': np.int64(1329),
#  'donald glover': np.int64(626),
#  'glover donald': np.int64(861),
#  'glover opening': np.int64(862),
#  'opening recent': np.int64(1378),
#  'recent health': np.int64(1622),
#  'health scare': np.int64(907),
#  'scare forced': np.int64(1815),
#  'forced tocancel': np.int64(818),
#  'tocancel tour': np.int64(2141),
#  'tour year': np.int64(2147),
#  'year time': np.int64(2370),
#  'time described': np.int64(2138),
#  'described ailment': np.int64(591),
#  'ailment glover': np.int64(125),
#  'glover said': np.int64(863),
#  'said saturday': np.int64(1771),
#  'saturday night': np.int64(1801),
#  'night performance': np.int64(1331),
#  'kpop': np.int64(1061),
#  'demon': np.int64(581),
#  'hunters': np.int64(947),
#  'officially': np.int64(1365),
#  'oscars': np.int64(1387),
#  'step': np.int64(1948),
#  'closer': np.int64(441),
#  'golden': np.int64(864),
#  'netflix': np.int64(1314),
#  'phenomenon': np.int64(1455),
#  '35': np.int64(50),
#  'features': np.int64(764),
#  'kpop demon': np.int64(1062),
#  'demon hunters': np.int64(582),
#  'hunters officially': np.int64(948),
#  'officially eligible': np.int64(1366),
#  'eligible oscars': np.int64(679),
#  'oscars kpop': np.int64(1388),
#  'hunters step': np.int64(949),
#  'step closer': np.int64(1949),
#  'closer golden': np.int64(442),
#  'golden moment': np.int64(865),
#  'moment oscars': np.int64(1233),
#  'oscars netflix': np.int64(1389),
#  'netflix phenomenon': np.int64(1315),
#  'phenomenon 35': np.int64(1456),
#  '35 films': np.int64(51),
#  'films features': np.int64(790),
#  'features eligible': np.int64(765),
#  'eligible animated': np.int64(678),
#  'feature film': np.int64(762),
#  'film category': np.int64(785),
#  'category 98th': np.int64(381),
#  'movie': np.int64(1249),
#  'guide': np.int64(890),
#  'coming': np.int64(453),
#  'september': np.int64(1847),
#  'christmas': np.int64(424),
#  'daniel': np.int64(540),
#  'craig': np.int64(511),
#  'sbenoit': np.int64(1810),
#  'blanc': np.int64(302),
#  'thestars': np.int64(2116),
#  'animals': np.int64(153),
#  'summer': np.int64(1988),
#  'known': np.int64(1059),
#  'sequel': np.int64(1849),
#  'twos': np.int64(2212),
#  'threes': np.int64(2126),
#  'play': np.int64(1472),
#  'big': np.int64(286),
#  'roles': np.int64(1736),
#  'movi': np.int64(1248),
#  'fall movie': np.int64(748),
#  'movie guide': np.int64(1250),
#  'guide films': np.int64(891),
#  'films coming': np.int64(789),
#  'coming september': np.int64(454),
#  'september christmas': np.int64(1848),
#  'christmas daniel': np.int64(425),
#  'daniel craig': np.int64(541),
#  'craig sbenoit': np.int64(512),
#  'sbenoit blanc': np.int64(1811),
#  'blanc thestars': np.int64(303),
#  'thestars wicked': np.int64(2117),
#  'wicked animals': np.int64(2317),
#  'animals zootopia': np.int64(154),
#  'zootopia summer': np.int64(2398),
#  'summer known': np.int64(1989),
#  'known sequel': np.int64(1060),
#  'sequel season': np.int64(1850),
#  'season twos': np.int64(1825),
#  'twos threes': np.int64(2213),
#  'threes play': np.int64(2127),
#  'play big': np.int64(1473),
#  'big roles': np.int64(289),
#  'roles fall': np.int64(1737),
#  'fall movi': np.int64(747),
#  'popular': np.int64(1502),
#  'soaring': np.int64(1930),
#  'global': np.int64(856),
#  'debut': np.int64(552),
#  'universal': np.int64(2225),
#  'pictures': np.int64(1461),
#  'gamblecontinues': np.int64(838),
#  'defy': np.int64(572),
#  'gravity': np.int64(880),
#  'just': np.int64(1034),
#  'onebrought': np.int64(1370),
#  'droves': np.int64(662),
#  'audiencesto': np.int64(232),
#  'theaters': np.int64(2103),
#  'country': np.int64(502),
#  'boug': np.int64(311),
#  'good popular': np.int64(869),
#  'popular soaring': np.int64(1503),
#  'soaring 226': np.int64(1931),
#  'million global': np.int64(1207),
#  'global debut': np.int64(857),
#  'debut universal': np.int64(554),
#  'universal pictures': np.int64(2226),
#  'pictures wicked': np.int64(1462),
#  'wicked gamblecontinues': np.int64(2318),
#  'gamblecontinues defy': np.int64(839),
#  'defy gravity': np.int64(573),
#  'gravity box': np.int64(881),
#  'office just': np.int64(1361),
#  'just year': np.int64(1036),
#  'year onebrought': np.int64(2367),
#  'onebrought droves': np.int64(1371),
#  'droves audiencesto': np.int64(663),
#  'audiencesto movie': np.int64(233),
#  'movie theaters': np.int64(1251),
#  'theaters country': np.int64(2104),
#  'country people': np.int64(503),
#  'people boug': np.int64(1439),
#  'races': np.int64(1590),
#  'past': np.int64(1423),
#  'running': np.int64(1754),
#  'magic': np.int64(1140),
#  'trick': np.int64(2163),
#  'installment': np.int64(987),
#  'thieving': np.int64(2120),
#  'magician': np.int64(1142),
#  'series': np.int64(1853),
#  'high': np.int64(912),
#  'profile': np.int64(1534),
#  'action': np.int64(99),
#  'pic': np.int64(1459),
#  'north': np.int64(1334),
#  'american': np.int64(136),
#  'lionsgate': np.int64(1116),
#  'races past': np.int64(1591),
#  'past running': np.int64(1424),
#  'running man': np.int64(1755),
#  'man box': np.int64(1164),
#  'office magic': np.int64(1362),
#  'magic trick': np.int64(1141),
#  'trick installment': np.int64(2164),
#  'installment thieving': np.int64(988),
#  'thieving magician': np.int64(2121),
#  'magician series': np.int64(1143),
#  'series beat': np.int64(1854),
#  'beat high': np.int64(274),
#  'high profile': np.int64(913),
#  'profile action': np.int64(1535),
#  'action pic': np.int64(100),
#  'pic running': np.int64(1460),
#  'man north': np.int64(1167),
#  'north american': np.int64(1335),
#  'american box': np.int64(137),
#  'office weekend': np.int64(1364),
#  'weekend lionsgate': np.int64(2310),
#  'predator': np.int64(1517),
#  'badlands': np.int64(264),
#  'tops': np.int64(2142),
#  '80': np.int64(84),
#  'worldwide': np.int64(2342),
#  'led': np.int64(1096),
#  '40': np.int64(55),
#  'according': np.int64(90),
#  'studio': np.int64(1982),
#  'estimates': np.int64(706),
#  'better': np.int64(281),
#  'expected': np.int64(728),
#  'result': np.int64(1673),
#  'slightly': np.int64(1913),
#  'lifted': np.int64(1104),
#  'bo': np.int64(304),
#  'predator badlands': np.int64(1518),
#  'badlands tops': np.int64(266),
#  'tops box': np.int64(2143),
#  'office 80': np.int64(1358),
#  '80 million': np.int64(85),
#  'million worldwide': np.int64(1213),
#  'worldwide new': np.int64(2343),
#  'york ap': np.int64(2378),
#  'ap predator': np.int64(182),
#  'badlands led': np.int64(265),
#  'led films': np.int64(1098),
#  'films north': np.int64(791),
#  'american theaters': np.int64(139),
#  'theaters debut': np.int64(2105),
#  'debut 40': np.int64(553),
#  '40 million': np.int64(57),
#  'million according': np.int64(1205),
#  'according studio': np.int64(92),
#  'studio estimates': np.int64(1983),
#  'estimates sunday': np.int64(707),
#  'sunday better': np.int64(1991),
#  'better expected': np.int64(282),
#  'expected result': np.int64(729),
#  'result slightly': np.int64(1674),
#  'slightly lifted': np.int64(1914),
#  'lifted bo': np.int64(1105),
#  'tesla': np.int64(2040),
#  'faces': np.int64(742),
#  'challenges': np.int64(397),
#  'amid': np.int64(140),
#  'declining': np.int64(566),
#  'sales': np.int64(1774),
#  'political': np.int64(1487),
#  'controversies': np.int64(491),
#  'regulatory': np.int64(1638),
#  'scrutiny': np.int64(1820),
#  'elon': np.int64(680),
#  'musk': np.int64(1256),
#  'secures': np.int64(1833),
#  'historic': np.int64(920),
#  'trillion': np.int64(2168),
#  'based': np.int64(270),
#  'pay': np.int64(1427),
#  'package': np.int64(1397),
#  'shareholders': np.int64(1867),
#  'headwinds': np.int64(904),
#  'investor': np.int64(1009),
#  'confidence': np.int64(476),
#  'remains': np.int64(1652),
#  'vision': np.int64(2267),
#  'transforming': np.int64(2158),
#  'ai': np.int64(122),
#  'robotics': np.int64(1728),
#  'leader': np.int64(1083),
#  'october': np.int64(1345),
#  'china': np.int64(419),
#  'fell': np.int64(776),
#  '006': np.int64(2),
#  'vehicles': np.int64(2251),
#  'lowest': np.int64(1136),
#  'years': np.int64(2372),
#  'market': np.int64(1173),
#  'share': np.int64(1862),
#  'dropped': np.int64(657),
#  'european': np.int64(710),
#  'declined': np.int64(564),
#  'sharply': np.int64(1884),
#  'drop': np.int64(654),
#  'germany': np.int64(849),
#  '75': np.int64(76),
#  'approved': np.int64(196),
#  'granting': np.int64(878),
#  '423': np.int64(60),
#  'shares': np.int64(1877),
#  'reaches': np.int64(1602),
#  'cap': np.int64(359),
#  'meets': np.int64(1195),
#  'aggressive': np.int64(114),
#  'targets': np.int64(2016),
#  'selling': np.int64(1841),
#  '20': np.int64(20),
#  'deploying': np.int64(588),
#  'robotaxis': np.int64(1726),
#  'robots': np.int64(1731),
#  'reported': np.int64(1660),
#  '37': np.int64(53),
#  'profit': np.int64(1536),
#  'decline': np.int64(561),
#  'q3': np.int64(1573),
#  'record': np.int64(1624),
#  'revenue': np.int64(1684),
#  '28': np.int64(46),
#  'driven': np.int64(647),
#  'minute': np.int64(1216),
#  'purchases': np.int64(1568),
#  '500': np.int64(62),
#  'ev': np.int64(715),
#  'tax': np.int64(2023),
#  'credit': np.int64(519),
#  'expired': np.int64(735),
#  'investigations': np.int64(1007),
#  'intensified': np.int64(996),
#  'nhtsa': np.int64(1325),
#  'probing': np.int64(1532),
#  '58': np.int64(66),
#  'incidents': np.int64(966),
#  'involving': np.int64(1018),
#  'self': np.int64(1839),
#  'driving': np.int64(651),
#  'delays': np.int64(574),
#  'crash': np.int64(513),
#  'reporting': np.int64(1666),
#  'company': np.int64(459),
#  'recalled': np.int64(1612),
#  '63': np.int64(72),
#  '000': np.int64(0),
#  'cybertrucks': np.int64(533),
#  'excessively': np.int64(720),
#  'bright': np.int64(325),
#  'headlights': np.int64(902),
#  'activities': np.int64(103),
#  'support': np.int64(1995),
#  'trump': np.int64(2187),
#  'far': np.int64(753),
#  'right': np.int64(1706),
#  'politicians': np.int64(1491),
#  'alienated': np.int64(130),
#  'environmentally': np.int64(696),
#  'conscious': np.int64(478),
#  'buyers': np.int64(342),
#  'costing': np.int64(500),
#  'estimated': np.int64(704),
#  '2022': np.int64(24),
#  'focus': np.int64(803),
#  'shifted': np.int64(1886),
#  'core': np.int64(493),
#  'automotive': np.int64(242),
#  'business': np.int64(337),
#  'accounts': np.int64(93),
#  'valuation': np.int64(2241),
#  'futuristic': np.int64(836),
#  'ventures': np.int64(2256),
#  'reflecting': np.int64(1633),
#  'risk': np.int64(1715),
#  'reward': np.int64(1692),
#  'trajectory': np.int64(2154),
#  'dependent': np.int64(586),
#  'leadership': np.int64(1086),
#  'tesla faces': np.int64(2059),
#  'faces significant': np.int64(743),
#  'significant challenges': np.int64(1906),
#  'challenges 2025': np.int64(398),
#  '2025 amid': np.int64(29),
#  'amid declining': np.int64(141),
#  'declining sales': np.int64(567),
#  'sales political': np.int64(1789),
#  'political controversies': np.int64(1490),
#  'controversies regulatory': np.int64(492),
#  'regulatory scrutiny': np.int64(1640),
#  'scrutiny elon': np.int64(1821),
#  'elon musk': np.int64(681),
#  'musk secures': np.int64(1286),
#  'secures historic': np.int64(1834),
#  'historic trillion': np.int64(921),
#  'trillion performance': np.int64(2173),
#  'performance based': np.int64(1442),
#  'based pay': np.int64(271),
#  'pay package': np.int64(1432),
#  'package shareholders': np.int64(1406),
#  'shareholders despite': np.int64(1872),
#  'despite headwinds': np.int64(593),
#  'headwinds investor': np.int64(905),
#  'investor confidence': np.int64(1010),
#  'confidence remains': np.int64(477),
#  'remains strong': np.int64(1653),
#  'strong musk': np.int64(1977),
#  'musk vision': np.int64(1294),
#  'vision transforming': np.int64(2269),
#  'transforming tesla': np.int64(2159),
#  'tesla ai': np.int64(2041),
#  'ai robotics': np.int64(123),
#  'robotics leader': np.int64(1729),
#  'leader october': np.int64(1085),
#  'october 2025': np.int64(1346),
#  '2025 tesla': np.int64(33),
#  'tesla china': np.int64(2052),
#  'china sales': np.int64(423),
#  'sales fell': np.int64(1780),
#  'fell 35': np.int64(777),
#  '35 year': np.int64(52),
#  'year year': np.int64(2371),
#  'year 26': np.int64(2360),
#  '26 006': np.int64(41),
#  '006 vehicles': np.int64(3),
#  'vehicles lowest': np.int64(2254),
#  'lowest years': np.int64(1137),
#  'years market': np.int64(2374),
#  'market share': np.int64(1179),
#  'share dropped': np.int64(1863),
#  'dropped european': np.int64(659),
#  'european sales': np.int64(712),
#  'sales declined': np.int64(1777),
#  'declined sharply': np.int64(565),
#  'sharply 40': np.int64(1885),
#  '40 drop': np.int64(56),
#  'drop germany': np.int64(655),
#  'germany november': np.int64(850),
#  'november 2025': np.int64(1341),
#  '2025 75': np.int64(28),
#  '75 tesla': np.int64(78),
#  'tesla shareholders': np.int64(2082),
#  'shareholders approved': np.int64(1870),
#  'approved pay': np.int64(199),
#  'package granting': np.int64(1400),
#  'granting musk': np.int64(879),
#  'musk 423': np.int64(1258),
#  '423 million': np.int64(61),
#  'million shares': np.int64(1211),
#  'shares tesla': np.int64(1880),
#  'tesla reaches': np.int64(2071),
#  'reaches trillion': np.int64(1603),
#  'trillion market': np.int64(2171),
#  'market cap': np.int64(1175),
#  'cap meets': np.int64(360),
#  'meets aggressive': np.int64(1196),
#  'aggressive targets': np.int64(115),
#  'targets including': np.int64(2018),
#  'including selling': np.int64(971),
#  'selling 20': np.int64(1842),
#  '20 million': np.int64(21),
#  'million vehicles': np.int64(1212),
#  'vehicles deploying': np.int64(2253),
#  'deploying million': np.int64(589),
#  'million robotaxis': np.int64(1209),
#  'robotaxis robots': np.int64(1727),
#  'robots tesla': np.int64(1733),
#  'tesla reported': np.int64(2076),
#  'reported 37': np.int64(1661),
#  '37 year': np.int64(54),
#  'year profit': np.int64(2369),
#  'profit decline': np.int64(1537),
#  'decline q3': np.int64(562),
#  'q3 2025': np.int64(1574),
#  '2025 despite': np.int64(30),
#  'despite record': np.int64(596),
#  'record revenue': np.int64(1627),
#  'revenue 28': np.int64(1685),
#  '28 billion': np.int64(47),
#  'billion driven': np.int64(295),
#  'driven minute': np.int64(648),
#  'minute purchases': np.int64(1217),
#  'purchases 500': np.int64(1569),
#  '500 ev': np.int64(64),
#  'ev tax': np.int64(717),
#  'tax credit': np.int64(2025),
#  'credit expired': np.int64(522),
#  'expired october': np.int64(736),
#  'october regulatory': np.int64(1349),
#  'regulatory investigations': np.int64(1639),
#  'investigations intensified': np.int64(1008),
#  'intensified nhtsa': np.int64(997),
#  'nhtsa probing': np.int64(1326),
#  'probing 58': np.int64(1533),
#  '58 incidents': np.int64(67),
#  'incidents involving': np.int64(968),
#  'involving tesla': np.int64(1020),
#  'tesla self': np.int64(2081),
#  'self driving': np.int64(1840),
#  ...}

# %%
from matplotlib.markers import MarkerStyle

def scatter_with_center(embed, title):
    fontsize = 10
    S = 40
    plt.figure(figsize=(8, 6), dpi=100)

    uniq = np.unique(y)
    palette = sns.color_palette('tab10', n_colors=len(uniq))
    color_map = dict(zip(uniq, palette))

    # 1. 先画所有散点（背景点）
    for lab in uniq:
        mask = y == lab
        plt.scatter(embed[mask, 0], embed[mask, 1],
                    c=[color_map[lab]], label=lab, s=S, alpha=.6)

    # 2. 给 topic 实例画彩色星星 + 文字
    topic_mask = df.role == 'topic'
    for idx_in_df in np.where(topic_mask)[0]:
        lab   = y[idx_in_df]
        x, y_coord = embed[idx_in_df]
        col = color_map[lab]

        # 画星
        plt.scatter(x, y_coord,
                    marker=MarkerStyle('*'),   # 五角星
                    s=280,                      # 星星大小
                    c=[col], edgecolors='black', linewidths=.6)

        # 文字稍微偏移
        topic_text = df.label.iloc[idx_in_df]
        short = (topic_text[:80] + '...') if len(topic_text) > 80 else topic_text
        plt.text(x + 0.05, y_coord + 0.05, short,
                 fontsize=fontsize,
                 bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))

    plt.title(title)
    plt.legend(fontsize=fontsize)
    plt.tight_layout()
    plt.show()

# %%
# 4.1 UMAP
umap_em = umap.UMAP(n_neighbors=30, min_dist=.3, metric='cosine', random_state=42).fit_transform(X)
scatter_with_center(umap_em, 'UMAP projection (colored by topic label)')
# Out:
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# 4.2 t-SNE
tsne_em = TSNE(n_components=2, metric='cosine', init='pca', random_state=42).fit_transform(X.toarray())
scatter_with_center(tsne_em, 't-SNE projection (colored by topic label)')
# Out:
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:350: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:351: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:355: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:355: RuntimeWarning: overflow encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:355: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:577: RuntimeWarning: divide by zero encountered in matmul
#   B = Q.T @ M
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:577: RuntimeWarning: overflow encountered in matmul
#   B = Q.T @ M
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:577: RuntimeWarning: invalid value encountered in matmul
#   B = Q.T @ M
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:590: RuntimeWarning: divide by zero encountered in matmul
#   U = Q @ Uhat
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:590: RuntimeWarning: overflow encountered in matmul
#   U = Q @ Uhat
# /Users/fengcong/miniconda3/envs/py312/lib/python3.12/site-packages/sklearn/utils/extmath.py:590: RuntimeWarning: invalid value encountered in matmul
#   U = Q @ Uhat
